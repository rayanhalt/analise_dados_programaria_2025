# %% [markdown]
# <a href="https://colab.research.google.com/github/rayanhalt/analise_dados_programaria_2025/blob/main/analise_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Introdução

# %% [markdown]
# Este notebook é parte do meu portfólio, desenvolvido durante o curso "Análise de Dados: meus primeiros passos em Python!" da Programaria.
#
# Aqui, aplico na prática o que já aprendi sobre análise de dados com Python, usando ferramentas como pandas, matplotlib e seaborn para explorar e visualizar dados reais.
#
# Meu foco foi investigar o mercado de trabalho na área de TI, com um olhar especial para a diversidade de gênero e raça. Analisei salários, níveis de escolaridade e outras variáveis importantes, buscando entender padrões e gerar insights relevantes.
#
# Além de reforçar meus conhecimentos técnicos, esse projeto também estimulou minha capacidade de estruturar análises, criar visualizações e comunicar resultados.
#
# Vamos lá?

# %% [markdown]
# #Uso da biblioteca Pandas

# %%
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd

# %%
dados = pd.read_excel('/content/drive/MyDrive/programaria /[programaria] planilha_modulo2.xlsx')

# %%
dados
# Out:
#                                     ID  IDADE FAIXA IDADE     GENERO  \
# 0     zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1     zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2     zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3     zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4     zfeuk2m9jozahicujlla8zfeuk2g7apj   29.0       25-29   Feminino
# ...                                ...    ...         ...        ...
# 4266  01jnrn9f6va0menfhk2ztm01jnrn96bp   26.0       25-29  Masculino
# 4267  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34   Feminino
# 4268  00zw9ks9d40z4u00zz3d20iix65qpli3   29.0       25-29  Masculino
# 4269  00xu7yujd7s57emj00xu7y0c3njix3de    NaN       17-21  Masculino
# 4270  00lb35llmdsidpa00lb35qcdysnzvhv7   24.0       22-24  Masculino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# ...

# %%
dados.head(10)
# Out:
#                                  ID  IDADE FAIXA IDADE     GENERO  \
# 0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4  zfeuk2m9jozahicujlla8zfeuk2g7apj   29.0       25-29   Feminino
# 5  ytrnz3zyvn791t3dum1ytrnz3zp22tmk   37.0       35-39   Feminino
# 6  zytlxsdgalh22cgrijvzytlxa49i8yzx   21.0       17-21  Masculino
# 7  xtakkr70pi8j3a1yjiogxaxtakk9wqo8   24.0       22-24   Feminino
# 8  zy4o5dk6iuxpdwgzy4o58xvd6ykwohrj   33.0       30-34  Masculino
# 9  xh5q34spt0f5z2zro9xh5qufedvfm8z8   36.0       35-39   Feminino
#
#   COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0          Parda  Não  Não acredito que minha experiência profissiona...
# 1          Parda  Não  Sim, acredito que a minha a experiência profis...
# ...

# %%
dados.tail()
# Out:
#                                     ID  IDADE FAIXA IDADE     GENERO  \
# 4266  01jnrn9f6va0menfhk2ztm01jnrn96bp   26.0       25-29  Masculino
# 4267  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34   Feminino
# 4268  00zw9ks9d40z4u00zz3d20iix65qpli3   29.0       25-29  Masculino
# 4269  00xu7yujd7s57emj00xu7y0c3njix3de    NaN       17-21  Masculino
# 4270  00lb35llmdsidpa00lb35qcdysnzvhv7   24.0       22-24  Masculino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 4266         Branca  Não                                                NaN
# 4267          Preta  Não  Não acredito que minha experiência profissiona...
# 4268         Branca  Não                                                NaN
# 4269         Branca  Não                                                NaN
# 4270         Branca  Não                                                NaN
#
#      ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL   ESTADO ONDE MORA  ...  \
# ...

# %%
dados.shape
# Out:
# (4271, 26)

# %%
len(dados)
# Out:
# 4271

# %%
dados.columns
# Out:
# Index(['ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA', 'PCD',
#        'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NIVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?'],
#       dtype='object')

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4271 entries, 0 to 4270
# Data columns (total 26 columns):
#  #   Column                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                     --------------  -----
#  0   ID                                                                                                                         4271 non-null   object
#  1   IDADE                                                                                                                      4197 non-null   float64
#  2   FAIXA IDADE                                                                                                                4271 non-null   object
# ...

# %% [markdown]
# #Repetindo análise do excel!

# %%
dados['GENERO']
# Out:
# 0       Masculino
# 1       Masculino
# 2       Masculino
# 3       Masculino
# 4        Feminino
#           ...
# 4266    Masculino
# 4267     Feminino
# 4268    Masculino
# 4269    Masculino
# 4270    Masculino
# Name: GENERO, Length: 4271, dtype: object

# %%
dados[dados['GENERO']=='Feminino']
#filtra tudo desclarado como feminino
# Out:
#                                     ID  IDADE FAIXA IDADE    GENERO  \
# 4     zfeuk2m9jozahicujlla8zfeuk2g7apj   29.0       25-29  Feminino
# 5     ytrnz3zyvn791t3dum1ytrnz3zp22tmk   37.0       35-39  Feminino
# 7     xtakkr70pi8j3a1yjiogxaxtakk9wqo8   24.0       22-24  Feminino
# 9     xh5q34spt0f5z2zro9xh5qufedvfm8z8   36.0       35-39  Feminino
# 10    w4ld9w5goe7503cq3jqfw4ld9wj49ma1   43.0       40-44  Feminino
# ...                                ...    ...         ...       ...
# 4248  1ny6d9up4mentx7g8w81ny68chvvxmy5   22.0       22-24  Feminino
# 4251  1nm2ykf9y983k8wnmm1npfpeng78r6ar   45.0       45-49  Feminino
# 4258  1awr6lvcvp7h1pgz1awr4dvy0fgcqxb1   25.0       25-29  Feminino
# 4259  0gxoe4lxwkz7g2w3t4d9bv0gxoe43zz6   26.0       25-29  Feminino
# 4267  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34  Feminino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# ...

# %%
dados[dados['GENERO']!="Masculino"]
#filtro tudo diferente de masculino
# Out:
#                                     ID  IDADE FAIXA IDADE    GENERO  \
# 4     zfeuk2m9jozahicujlla8zfeuk2g7apj   29.0       25-29  Feminino
# 5     ytrnz3zyvn791t3dum1ytrnz3zp22tmk   37.0       35-39  Feminino
# 7     xtakkr70pi8j3a1yjiogxaxtakk9wqo8   24.0       22-24  Feminino
# 9     xh5q34spt0f5z2zro9xh5qufedvfm8z8   36.0       35-39  Feminino
# 10    w4ld9w5goe7503cq3jqfw4ld9wj49ma1   43.0       40-44  Feminino
# ...                                ...    ...         ...       ...
# 4248  1ny6d9up4mentx7g8w81ny68chvvxmy5   22.0       22-24  Feminino
# 4251  1nm2ykf9y983k8wnmm1npfpeng78r6ar   45.0       45-49  Feminino
# 4258  1awr6lvcvp7h1pgz1awr4dvy0fgcqxb1   25.0       25-29  Feminino
# 4259  0gxoe4lxwkz7g2w3t4d9bv0gxoe43zz6   26.0       25-29  Feminino
# 4267  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34  Feminino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# ...

# %%
dados[dados['GENERO'].str.contains('não', na=False)]
#todos os valores da coluna genero que contenha não (prefiro não informar)
# Out:
#                                     ID  IDADE FAIXA IDADE  \
# 562   vhuw8xnpbmj6oh20xovhuwcbdl4a12ni   29.0       25-29
# 1528  n2ktdn33istvlu1ha4v3kn2ktdn1rsp1    NaN         55+
# 1913  k3as6jdh3w4jf4ztsw4kpkk3as6jdy19   30.0       30-34
# 1925  jzppdwep2kpisqjjzppdh304v83cj7eu    NaN       17-21
# 2554  f5l206z0hr9uh3nz2iiff5l206c0g10o   20.0       17-21
# 3090  a6ugmsw7s8hu5aa6uglio5apj74fam9o   26.0       25-29
# 3357  7q0icczxn0l3a894cbx7q0icczjyud0n   29.0       25-29
# 3493  6m8haop6lxnaizpwij6m8haopiax98jg   25.0       25-29
# 3610  5mloglozmr0r715mntaxbt6xy8b5olmb   30.0       30-34
# 4171  0rksyxnqhn13nwytwi6y0rkssx6jmodf   26.0       25-29
# 4200  0liu228yff8fnm3zeuahsx0liu228y07   28.0       25-29
# 4227  0eqzo5w2l5wizswvwywt8h0eqzo5yucv   28.0       25-29
#
#                     GENERO        COR/RACA/ETNIA                   PCD  \
# 562   Prefiro não informar                 Parda                   Não
# ...

# %%
dados[dados['IDADE']>=30]
#filtra todas as pessoas >30 anos
# Out:
#                                     ID  IDADE FAIXA IDADE     GENERO  \
# 0     zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1     zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2     zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 5     ytrnz3zyvn791t3dum1ytrnz3zp22tmk   37.0       35-39   Feminino
# 8     zy4o5dk6iuxpdwgzy4o58xvd6ykwohrj   33.0       30-34  Masculino
# ...                                ...    ...         ...        ...
# 4260  03atvow8404tatt2iixjds03atvownkz   36.0       35-39  Masculino
# 4261  02xomoejng6c9152kde02xomww412qpg   33.0       30-34  Masculino
# 4262  02vlm03c29g3fcys8tj06102vlm0983h   31.0       30-34  Masculino
# 4264  028mfisr3mqazkn5n6swe028mt55nqzq   37.0       35-39  Masculino
# 4267  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34   Feminino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# ...

# %%
dados[(dados['IDADE']>30) & (dados['GENERO']== 'Feminino')]
# Out:
#                                     ID  IDADE FAIXA IDADE    GENERO  \
# 5     ytrnz3zyvn791t3dum1ytrnz3zp22tmk   37.0       35-39  Feminino
# 9     xh5q34spt0f5z2zro9xh5qufedvfm8z8   36.0       35-39  Feminino
# 10    w4ld9w5goe7503cq3jqfw4ld9wj49ma1   43.0       40-44  Feminino
# 19    vaw950izv5zvkx3wu7a1vaw950m97zvm   35.0       35-39  Feminino
# 23    v9cagsq6dcf02v9clwn23i01yohn9lwn   43.0       40-44  Feminino
# ...                                ...    ...         ...       ...
# 4229  3u5sqtrbx3jssjpv3u5sai3r33djb2n1   46.0       45-49  Feminino
# 4239  3exhv7qxlixzv3jyxtbrxd3ex8479ngv   32.0       30-34  Feminino
# 4240  2d3y91xi5jh3xuo7mz2a7kl2d3y91xjf   32.0       30-34  Feminino
# 4251  1nm2ykf9y983k8wnmm1npfpeng78r6ar   45.0       45-49  Feminino
# 4267  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34  Feminino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# ...

# %%
dados[dados['COR/RACA/ETNIA']=='Amarela']
# Out:
#                                     ID  IDADE FAIXA IDADE     GENERO  \
# 4     zfeuk2m9jozahicujlla8zfeuk2g7apj   29.0       25-29   Feminino
# 5     ytrnz3zyvn791t3dum1ytrnz3zp22tmk   37.0       35-39   Feminino
# 7     xtakkr70pi8j3a1yjiogxaxtakk9wqo8   24.0       22-24   Feminino
# 9     xh5q34spt0f5z2zro9xh5qufedvfm8z8   36.0       35-39   Feminino
# 10    w4ld9w5goe7503cq3jqfw4ld9wj49ma1   43.0       40-44   Feminino
# ...                                ...    ...         ...        ...
# 3915  32ql2lb9wp4clgthf32ql21lcb1jg8wx   31.0       30-34  Masculino
# 3935  2x6s1hdx40ww2r67bw2x8kanq2yo78td   36.0       35-39  Masculino
# 4000  2baf3bx82w0sh88q3eikkl92baf3bx8f   41.0       40-44  Masculino
# 4257  043snvbsxn3fuyfe043j5comuyu8g6ba   46.0       45-49  Masculino
# 4262  02vlm03c29g3fcys8tj06102vlm0983h   31.0       30-34  Masculino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# ...

# %%
dados[dados['IDADE']<40]
# Out:
#                                     ID  IDADE FAIXA IDADE     GENERO  \
# 0     zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1     zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 3     zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4     zfeuk2m9jozahicujlla8zfeuk2g7apj   29.0       25-29   Feminino
# 5     ytrnz3zyvn791t3dum1ytrnz3zp22tmk   37.0       35-39   Feminino
# ...                                ...    ...         ...        ...
# 4265  01nmlhyw8w2b4stchg01nmlvlcqp0iis   28.0       25-29  Masculino
# 4266  01jnrn9f6va0menfhk2ztm01jnrn96bp   26.0       25-29  Masculino
# 4267  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34   Feminino
# 4268  00zw9ks9d40z4u00zz3d20iix65qpli3   29.0       25-29  Masculino
# 4270  00lb35llmdsidpa00lb35qcdysnzvhv7   24.0       22-24  Masculino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# ...

# %%
dados[(dados['COR/RACA/ETNIA'] == 'Amarela') & (dados['IDADE'] < 40)]
#desafio aula filtro cor amarela + pessoas >40 anos
# Out:
#                                     ID  IDADE FAIXA IDADE     GENERO  \
# 4     zfeuk2m9jozahicujlla8zfeuk2g7apj   29.0       25-29   Feminino
# 5     ytrnz3zyvn791t3dum1ytrnz3zp22tmk   37.0       35-39   Feminino
# 7     xtakkr70pi8j3a1yjiogxaxtakk9wqo8   24.0       22-24   Feminino
# 9     xh5q34spt0f5z2zro9xh5qufedvfm8z8   36.0       35-39   Feminino
# 13    zwh83jpy6x40b95xigsr2zwh83jpflu3   24.0       22-24  Masculino
# ...                                ...    ...         ...        ...
# 3798  40vyha5ppui9ljh40vyhadcq5g7gjc2r   36.0       35-39  Masculino
# 3840  3r1le1pxfieachv03r1le1tfqz2axaft   27.0       25-29  Masculino
# 3915  32ql2lb9wp4clgthf32ql21lcb1jg8wx   31.0       30-34  Masculino
# 3935  2x6s1hdx40ww2r67bw2x8kanq2yo78td   36.0       35-39  Masculino
# 4262  02vlm03c29g3fcys8tj06102vlm0983h   31.0       30-34  Masculino
#
#      COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# ...

# %%
dados.groupby('GENERO')['ID'].nunique()
#agrupamento por gênero
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# Name: ID, dtype: int64

# %%
dados.groupby('GENERO', dropna=False)['ID'].nunique()
#puxando os valores nulos tb
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# NaN                        9
# Name: ID, dtype: int64

# %%
dados['GENERO'].value_counts(dropna=False)
#contagens usando value.conts
# Out:
# GENERO
# Masculino               3194
# Feminino                1056
# Prefiro não informar      12
# NaN                        9
# Name: count, dtype: int64

# %%
dados[dados['IDADE']>30]['NIVEL'].value_counts()
#filtros y contagens
# Out:
# NIVEL
# Sênior    525
# Pleno     408
# Júnior    274
# Name: count, dtype: int64

# %%
dados[(dados['IDADE']>30) & (dados['GENERO']=='Feminino')]['NIVEL'].value_counts()
#2 filtros (idde e genero) e contagem por nivel
# Out:
# NIVEL
# Pleno     117
# Sênior    114
# Júnior     96
# Name: count, dtype: int64

# %%
#usando a tabela dinâmica no Pandas para filtrar pessoas gestoras por gênero
pd.pivot_table(dados, values=['ID'], index=['GENERO'], columns=['GESTOR?'], aggfunc='count')
# Out:
#                         ID
# GESTOR?              False True
# GENERO
# Feminino               754   132
# Masculino             2212   578
# Prefiro não informar     9     2

# %% [markdown]
# #Estatística Básica

# %%
import numpy as np

# %%
lista_idades=[26,30,32,22,26,35,40,20,43,31,23]

# %%
np.sum(lista_idades)
#soma
# Out:
# np.int64(328)

# %%
len(lista_idades)
#identificando quantidade de idades (len)
# Out:
# 11

# %%
np.sum(lista_idades)/len(lista_idades)
#média das idades
# Out:
# np.float64(29.818181818181817)

# %%
media = np.mean(lista_idades)
print("média aritmética", media)
#outra forma de fazer a média
# Out:
# média aritmética 29.818181818181817

# %%
mediana = np.median(lista_idades)
mediana
#mediana dos valores
# Out:
# np.float64(30.0)

# %%
dados['IDADE'].mean()
#média usando nossa tabela de dados
# Out:
# np.float64(31.169168453657374)

# %% [markdown]
# #Desafio
# Faça a média da idade de quem respondeu ser do gênero masculino, assim como as estatísticas da coluna de salário

# %%
import pandas as pd
dados = pd.read_excel('/content/drive/MyDrive/programaria /planilha_modulo3.xlsx')

# %%
dados[dados['GENERO']=='Masculino']['IDADE'].mean()
# Out:
# np.float64(31.147876077930373)

# %%
dados[dados['GENERO']=='Feminino']['IDADE'].mean()
# Out:
# np.float64(31.318051575931232)

# %%
dados[dados['GENERO']=='Masculino']['SALARIO'].mean()
# Out:
# np.float64(11724.552688172043)

# %%
dados[dados['GENERO']=='Feminino']['SALARIO'].mean()
# Out:
# np.float64(8673.22460496614)

# %%
comparativo_salario = dados.groupby('GENERO')['SALARIO'].mean().reset_index()
print(comparativo_salario)
# Out:
#                  GENERO       SALARIO
# 0              Feminino   8673.224605
# 1             Masculino  11724.552688
# 2  Prefiro não informar   7694.545455

# %% [markdown]
# #Valores Faltantes

# %%
import pandas as pd
dados = pd.read_excel('/content/drive/MyDrive/programaria /planilha_modulo3.xlsx')

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4271 entries, 0 to 4270
# Data columns (total 28 columns):
#  #   Column                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                     --------------  -----
#  0   Unnamed: 0                                                                                                                 4271 non-null   int64
#  1   ID                                                                                                                         4271 non-null   object
#  2   IDADE                                                                                                                      4197 non-null   float64
# ...

# %% [markdown]
# ###Trabalhando coluna de gênero

# %%
#função preenchendo valores nulos
dados['GENERO']= dados['GENERO'].fillna("Prefiro não informar")

# %%
import pandas as pd
dados = pd.read_excel('/content/drive/MyDrive/programaria /planilha_modulo3.xlsx')

# %%
dados.groupby('GENERO',dropna=False)['ID'].nunique()
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# NaN                        9
# Name: ID, dtype: int64

# %% [markdown]
# ###Trabalhando coluna de idade

# %%
dados['IDADE'].isnull().value_counts()
# Out:
# IDADE
# False    4197
# True       74
# Name: count, dtype: int64

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NIVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO'],
#       dtype='object')

# %%
dados[dados['IDADE'].isnull()]['FAIXA IDADE'].value_counts()
# Out:
# FAIXA IDADE
# 55+      68
# 17-21     6
# Name: count, dtype: int64

# %%
media_17_21 = dados[dados['FAIXA IDADE']=='17-21']['IDADE'].mean()

# %%
dados.loc[(dados['FAIXA IDADE']==17-21) & (dados['IDADE'].isnull()),'IDADE'] = media_17_21

# %%
dados[dados['IDADE'].isnull()]['FAIXA IDADE'].value_counts()
# Out:
# FAIXA IDADE
# 55+      68
# 17-21     6
# Name: count, dtype: int64

# %%
dados[dados['FAIXA IDADE']=='55+']['IDADE']
# Out:
# 9      NaN
# 66     NaN
# 96     NaN
# 121    NaN
# 156    NaN
#         ..
# 4001   NaN
# 4043   NaN
# 4048   NaN
# 4061   NaN
# 4215   NaN
# Name: IDADE, Length: 68, dtype: float64

# %%
dados[dados['FAIXA IDADE']=='55+']['NIVEL']
# Out:
# 9        Pleno
# 66      Júnior
# 96       Pleno
# 121      Pleno
# 156     Júnior
#          ...
# 4001       NaN
# 4043       NaN
# 4048       NaN
# 4061       NaN
# 4215    Sênior
# Name: NIVEL, Length: 68, dtype: object

# %%
media_geral=dados['IDADE'].mean()
media_geral
# Out:
# np.float64(31.169168453657374)

# %%
dados.loc[(dados['FAIXA IDADE']=='55+') & (dados['IDADE'].isnull()),'IDADE'] =  media_geral

# %%
medias_por_faixa = dados.groupby('FAIXA IDADE')['IDADE'].mean()

# %%
for faixa, media in medias_por_faixa.items():
    dados.loc[(dados['FAIXA IDADE'] == faixa) & (dados['IDADE'].isnull()), 'IDADE'] = media

# %%
dados[dados['IDADE'].isnull()]['FAIXA IDADE'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# ###Tratando coluna salário

# %%
dados[dados['SALARIO'].isnull()]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 12            12  zwr9hqcpg513kaopenzwr9hibaqmldto   31.0       30-34
# 28            28  ztgepgj82o9oix0nztgepq2trcay6gpv   24.0       22-24
# 34            34  zsa9i6njd3e594mw0tvlk4zsa9iw86i9   24.0       22-24
# 39            39  zr4b2vm7dapp3linwqwn7zr4b2vmagqx   32.0       30-34
# 63            63  zm7o5yquakof0j6zm7vh3o0letznhdvh   26.0       25-29
# ...          ...                               ...    ...         ...
# 4242        4242  09oxwp6lsdwhw09ox1uobuxa8cq2pzma   26.0       25-29
# 4252        4252  064pe9b1htw7mflhif064pe95dotv6yf   39.0       35-39
# 4258        4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw   25.0       25-29
# 4260        4260  03atvow8404tatt2iixjds03atvownkz   36.0       35-39
# 4261        4261  02xomoejng6c9152kde02xomww412qpg   33.0       30-34
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 12    Masculino         Branca  Não
# 28     Feminino          Parda  Não
# ...

# %%
dados[dados['SALARIO'].isnull()]['FAIXA SALARIAL'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
mediana_salario = dados['SALARIO'].median()

# %%
dados.loc[dados['SALARIO'].isnull(), 'SALARIO'] = mediana_salario

# %% [markdown]
# #Exercício licitações

# %%
caminho = '/content/drive/MyDrive/programaria /licitacoes.csv'
#importando os novos dados

# %%
import pandas as pd
licitacoes = pd.read_csv(caminho, encoding='latin1', sep=';')
#deu erro de formato então ajustei para ler o ';'

# %%
licitacoes.head()
# Out:
#    Número Licitação  Código UG                                       Nome UG  \
# 0             12016     160438     COMANDO 2 BRIGADA DE CAVALARIA MECANIZADA
# 1             12017     160203       2º BATALHAO DE ENGENHARIA DE CONSTRUCAO
# 2             12017     193002  DEPARTAMENTO NACIONAL DE OBRAS CONT.AS SECAS
# 3             12018     925135              BANCO CENTRAL DO BRASIL - RECIFE
# 4             12018     110101     GABINETE DA VICE-PRESIDENCIA DA REPUBLICA
#
#    Código Modalidade Compra             Modalidade Compra    Número Processo  \
# 0                       -99    Pregão - Registro de Preço  80871182401201629
# 1                         3                  Concorrência  64040053530201713
# 2                         2              Tomada de Preços  59400003079201636
# 3                         6         Dispensa de Licitação             148097
# 4                         7  Inexigibilidade de Licitação  00300000433201818
#
# ...

# %%
licitacoes.isnull().sum()
#encontrando os dados faltantes
# Out:
# Número Licitação                0
# Código UG                       0
# Nome UG                         0
# Código Modalidade Compra        0
# Modalidade Compra               0
# Número Processo                 0
# Objeto                          0
# Situação Licitação              0
# Código Órgão Superior           0
# Nome Órgão Superior             0
# Código Órgão                    0
# Nome Órgão                      0
# UF                              0
# Município                       0
# Data Resultado Compra           0
# Data Abertura               10648
# Valor Licitação                 0
# dtype: int64

# %%
licitacoes['Data Abertura'].fillna(licitacoes['Data Resultado Compra'], inplace=True)
# Out:
# <ipython-input-67-1379c51b8b83>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   licitacoes['Data Abertura'].fillna(licitacoes['Data Resultado Compra'], inplace=True)

# %%
licitacoes.isnull().sum()
# Out:
# Número Licitação            0
# Código UG                   0
# Nome UG                     0
# Código Modalidade Compra    0
# Modalidade Compra           0
# Número Processo             0
# Objeto                      0
# Situação Licitação          0
# Código Órgão Superior       0
# Nome Órgão Superior         0
# Código Órgão                0
# Nome Órgão                  0
# UF                          0
# Município                   0
# Data Resultado Compra       0
# Data Abertura               0
# Valor Licitação             0
# dtype: int64

# %% [markdown]
# #Valores discrepantes (outliers)

# %%
lista_idades = [26,30,32,22,26,35,400,20,43,31,23]

# %%
import numpy as np

# %%
media = np.mean(lista_idades)

# %%
desvio = np.std(lista_idades)

# %%
media + 3*desvio #limite superior
# Out:
# np.float64(383.2314444674207)

# %%
media - 3*desvio #limite inferior
# Out:
# np.float64(-258.1405353765116)

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(lista_idades)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc8e6c96510>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fc8e6ed0650>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc8e6c97e10>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc8e6ed0dd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc8e6ed0350>],
#  'means': []}

# %%
plt.boxplot(dados['SALARIO'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc8e6c49210>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fc8e6b55390>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc8e6b7f890>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc8e6b57ed0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc8e6b56bd0>],
#  'means': []}

# %%
Q1 = dados['SALARIO'].quantile(0.25)
Q1
# Out:
# np.float64(4751.5)

# %%
Q3 = dados ['SALARIO'].quantile(0.75)
Q3
# Out:
# np.float64(11794.5)

# %%
IQR = Q3-Q1
IQR
# Out:
# np.float64(7043.0)

# %%
lim_superior = Q3 + (1.5*IQR)
lim_superior
# Out:
# np.float64(22359.0)

# %%
lim_inferior = Q1 - (1.5*IQR)
lim_inferior
# Out:
# np.float64(-5813.0)

# %%
dados['FAIXA SALARIAL'].value_counts()
# Out:
# FAIXA SALARIAL
# de R$ 8.001/mês a R$ 12.000/mês     752
# de R$ 4.001/mês a R$ 6.000/mês      584
# de R$ 6.001/mês a R$ 8.000/mês      527
# de R$ 12.001/mês a R$ 16.000/mês    437
# de R$ 3.001/mês a R$ 4.000/mês      303
# de R$ 2.001/mês a R$ 3.000/mês      285
# de R$ 16.001/mês a R$ 20.000/mês    229
# de R$ 1.001/mês a R$ 2.000/mês      216
# de R$ 20.001/mês a R$ 25.000/mês    134
# de R$ 25.001/mês a R$ 30.000/mês     77
# de R$ 30.001/mês a R$ 40.000/mês     70
# Acima de R$ 40.001/mês               45
# Menos de R$ 1.000/mês                35
# Name: count, dtype: int64

# %%
media_salario = dados ['SALARIO'].mean()
media_salario
# Out:
# np.float64(10517.53348162023)

# %%
desvio_salario = dados ['SALARIO'].std()
desvio_salario
# Out:
# 18096.210989118474

# %%
limite_superior = media_salario + (3*desvio_salario)
limite_superior
# Out:
# np.float64(64806.16644897565)

# %%
dados[dados['SALARIO']>limite_superior]['FAIXA SALARIAL'].value_counts()
# Out:
# FAIXA SALARIAL
# Acima de R$ 40.001/mês              19
# de R$ 30.001/mês a R$ 40.000/mês     3
# Name: count, dtype: int64

# %%
media_30_40 = dados[(dados['FAIXA SALARIAL']=='de R$ 30.001/mês a R$ 40.000/mês') & (dados['SALARIO']<limite_superior)]['SALARIO'].mean()

# %%
dados.loc[(dados['FAIXA SALARIAL']=='de R$ 30.001/mês a R$ 40.000/mês') & (dados['SALARIO']>limite_superior), 'SALARIO'] = media_30_40

# %%
dados[dados['SALARIO']>limite_superior]['FAIXA SALARIAL'].value_counts()
# Out:
# FAIXA SALARIAL
# Acima de R$ 40.001/mês    19
# Name: count, dtype: int64

# %%
media_40 = dados[(dados['FAIXA SALARIAL']=='Acima de R$ 40.001/mês') & (dados['SALARIO']<limite_superior)]['SALARIO'].mean()
media_40 #media dos salários >40k/mês
# Out:
# np.float64(53127.846153846156)

# %%
dados.loc[(dados['FAIXA SALARIAL']=='Acima de R$ 40.001/mês') & (dados['SALARIO']>limite_superior), 'SALARIO'] = media_40

# %%
dados[dados['SALARIO']>limite_superior]['FAIXA SALARIAL'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
#verificando o resultado
plt.boxplot(dados['SALARIO'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc8e4393b10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fc8e43acfd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc8e439f4d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc8e43ae3d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc8e43aecd0>],
#  'means': []}

# %% [markdown]
# #Distribuição Amostral e intervalo de confiança

# %%
salarios = dados ['SALARIO']

# %%
salarios
# Out:
# 0       11194.0
# 1        4695.0
# 2       14202.0
# 3       15463.0
# 4        7733.0
#          ...
# 4266     4329.0
# 4267     3758.0
# 4268    19607.0
# 4269      989.0
# 4270     3079.0
# Name: SALARIO, Length: 4271, dtype: float64

# %%
media_amostral = np.mean(salarios)
media_amostral
# Out:
# np.float64(9904.390109813306)

# %%
desvio_amostral = np.std(salarios)
desvio_amostral
# Out:
# 8306.104872579343

# %%
nivel_confianca = 0.95

# %%
tamanho_amostra = len(salarios)
tamanho_amostra
# Out:
# 4271

# %%
from scipy import stats

# %%
erro_padrao = stats.sem(salarios)
erro_padrao
# Out:
# np.float64(127.11109872023638)

# %%
intervalo_confianca = stats.t.interval(nivel_confianca, tamanho_amostra-1, loc=media_amostral, scale=erro_padrao)
intervalo_confianca
# Out:
# (np.float64(9655.186295869078), np.float64(10153.593923757535))

# %% [markdown]
# #Desafio
# Calcular com 90% de confiança qual a média salarial por cargo e gênero

# %%
media_cargo_genero = dados.groupby(['CARGO ATUAL', 'GENERO'])['SALARIO'].mean().reset_index()
media_cargo_genero
# Out:
#                                           CARGO ATUAL                GENERO  \
# 0                           Analista de BI/BI Analyst              Feminino
# 1                           Analista de BI/BI Analyst             Masculino
# 2                      Analista de Dados/Data Analyst              Feminino
# 3                      Analista de Dados/Data Analyst             Masculino
# 4                      Analista de Dados/Data Analyst  Prefiro não informar
# 5   Analista de Inteligência de Mercado/Market Int...              Feminino
# 6   Analista de Inteligência de Mercado/Market Int...             Masculino
# 7                               Analista de Marketing              Feminino
# 8                               Analista de Marketing             Masculino
# 9               Analista de Negócios/Business Analyst              Feminino
# 10              Analista de Negócios/Business Analyst             Masculino
# ...

# %%
desvio_cargo_genero = dados.groupby(['CARGO ATUAL', 'GENERO'])['SALARIO'].std().reset_index()
desvio_cargo_genero
# Out:
#                                           CARGO ATUAL                GENERO  \
# 0                           Analista de BI/BI Analyst              Feminino
# 1                           Analista de BI/BI Analyst             Masculino
# 2                      Analista de Dados/Data Analyst              Feminino
# 3                      Analista de Dados/Data Analyst             Masculino
# 4                      Analista de Dados/Data Analyst  Prefiro não informar
# 5   Analista de Inteligência de Mercado/Market Int...              Feminino
# 6   Analista de Inteligência de Mercado/Market Int...             Masculino
# 7                               Analista de Marketing              Feminino
# 8                               Analista de Marketing             Masculino
# 9               Analista de Negócios/Business Analyst              Feminino
# 10              Analista de Negócios/Business Analyst             Masculino
# ...

# %%
erro_padrao = dados.groupby(['CARGO ATUAL', 'GENERO'])['SALARIO'].count().reset_index(name='n')
erro_padrao
# Out:
#                                           CARGO ATUAL                GENERO  \
# 0                           Analista de BI/BI Analyst              Feminino
# 1                           Analista de BI/BI Analyst             Masculino
# 2                      Analista de Dados/Data Analyst              Feminino
# 3                      Analista de Dados/Data Analyst             Masculino
# 4                      Analista de Dados/Data Analyst  Prefiro não informar
# 5   Analista de Inteligência de Mercado/Market Int...              Feminino
# 6   Analista de Inteligência de Mercado/Market Int...             Masculino
# 7                               Analista de Marketing              Feminino
# 8                               Analista de Marketing             Masculino
# 9               Analista de Negócios/Business Analyst              Feminino
# 10              Analista de Negócios/Business Analyst             Masculino
# ...

# %%
desafio_results = dados.groupby(['CARGO ATUAL', 'GENERO'])['SALARIO'].agg(['mean', 'std', 'count']).reset_index()
desafio_results
# Out:
#                                           CARGO ATUAL                GENERO  \
# 0                           Analista de BI/BI Analyst              Feminino
# 1                           Analista de BI/BI Analyst             Masculino
# 2                      Analista de Dados/Data Analyst              Feminino
# 3                      Analista de Dados/Data Analyst             Masculino
# 4                      Analista de Dados/Data Analyst  Prefiro não informar
# 5   Analista de Inteligência de Mercado/Market Int...              Feminino
# 6   Analista de Inteligência de Mercado/Market Int...             Masculino
# 7                               Analista de Marketing              Feminino
# 8                               Analista de Marketing             Masculino
# 9               Analista de Negócios/Business Analyst              Feminino
# 10              Analista de Negócios/Business Analyst             Masculino
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,6))  # Ajuste do tamanho da figura

sns.boxplot(data=dados, x='CARGO ATUAL', y='SALARIO', hue='GENERO')

plt.title('Distribuição Salarial por Cargo e Gênero')
plt.xlabel('Cargo')
plt.ylabel('Salário')
plt.xticks(rotation=45)  # Rotacionar para visualizar melhor

plt.legend(title='Gênero')
plt.show()

# %% [markdown]
# #Featuring engineering

# %%
def preencher_nivel(gestor, nivel):
  if gestor==1:
    return "Pessoa Gestora"
  else:
    return nivel

# %%
dados['NOVO NIVEL'] = dados.apply(lambda x: preencher_nivel(x['GESTOR?'], x['NIVEL']), axis=1)

# %%
dados['NOVO NIVEL'].value_counts()
# Out:
# NOVO NIVEL
# Pleno             1060
# Júnior            1023
# Sênior             898
# Pessoa Gestora     713
# Name: count, dtype: int64

# %%
dados = pd.get_dummies(dados,columns=['NIVEL'])

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior'],
#       dtype='object')

# %%
def determinar_geracao(idade):
  if 39<idade<=58:
    return "Geração X"
  elif 29< idade <=39:
    return "Millenial"
  elif 13<=idade<=29:
    return "Geração Z"
  else:
    return "Outra geração"

# %%
dados['GERACAO'] = dados ['IDADE'].apply(determinar_geracao)

# %%
dados ['GERACAO'].value_counts()
# Out:
# GERACAO
# Geração Z    1999
# Millenial    1761
# Geração X     511
# Name: count, dtype: int64

# %% [markdown]
# ###unindo 2 tabelas

# %%
dados2 = pd.read_excel('/content/drive/MyDrive/programaria /Planilha_Aula_parte2.xlsx')

# %%
dados2.head()
# Out:
#                                  ID  \
# 0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96
# 1  zzls2oftfn9law393oezzls2ofhvfpzd
# 2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi
# 3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl
# 4  zzaf1m95yan929rb94wzzaf1mekhvhpg
#
#   Quanto tempo de experiência na área de dados você tem?  \
# 0                                      de 1 a 2 anos
# 1                                      de 3 a 4 anos
# 2                                      de 3 a 4 anos
# 3                                      de 4 a 6 anos
# 4             Não tenho experiência na área de dados
#
#   Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?  \
# 0                                     de 7 a 10 anos
# 1                                     Menos de 1 ano
# 2                                    Mais de 10 anos
# 3  Não tive experiência na área de TI/Engenharia ...
# 4                                    Mais de 10 anos
#
# ...

# %%
dados = dados.merge(dados2, on= 'ID', how= 'left')

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERACAO', 'Quanto tempo de experiência na área de dados você tem?',
# ...

# %%
dados["Você pretende mudar de emprego nos próximos 6 meses?"].value_counts()
# Out:
# Você pretende mudar de emprego nos próximos 6 meses?
# Não estou buscando, mas me considero aberto a outras oportunidades         1354
# Estou em busca de oportunidades dentro ou fora do Brasil                   1011
# Não estou buscando e não pretendo mudar de emprego nos próximos 6 meses     978
# Estou em busca de oportunidades, mas apenas fora do Brasil                  353
# Name: count, dtype: int64

# %%
#Será que a pessoa está em busca de emprego ou aberta a oportunidades? Vamos descobrir!

# %%
dados['EM BUSCA?'] = dados["Você pretende mudar de emprego nos próximos 6 meses?"].str.contains("em busca", case=False )

# %%
dados['EM BUSCA?'].value_counts()
# Out:
# EM BUSCA?
# False    2332
# True     1364
# Name: count, dtype: int64

# %%
dados['ABERTO A OPORTUDADES!'] = dados["Você pretende mudar de emprego nos próximos 6 meses?"].str.contains("ABERTO", case=False )

# %%
dados['ABERTO A OPORTUDADES!'].value_counts()
# Out:
# ABERTO A OPORTUDADES!
# False    2342
# True     1354
# Name: count, dtype: int64

# %% [markdown]
# #Desafio
# Crie uma nova coluna de etnia, simplificando a categoria para branca, não branca e outros.
# Vocês irão criar uma coluna nova e usar a coluna de etnia para criar essas novas variáveis.

# %%
def simplificar_etnia(etnia):
    if etnia == "Branca":
        return "Branca"
    elif etnia in ["Preta", "Parda", "Amarela", "Indígena"]:
        return "Não branca"
    else:
        return "Outros"

# Criar nova coluna
dados['ETNIA_SIMPLIFICADA'] = dados['COR/RACA/ETNIA'].apply(simplificar_etnia)

# %%
dados['ETNIA_SIMPLIFICADA'].value_counts()
# Out:
# ETNIA_SIMPLIFICADA
# Branca        2746
# Não branca    1484
# Outros          43
# Name: count, dtype: int64

# %% [markdown]
# #Correlação
# Será que quanto mais uma pessoa envelhece, maior o salário dela?

# %%
correlacao_continua = dados['IDADE'].corr(dados['SALARIO'])
correlacao_continua
#apesar de existir uma correlação positiva ela ta bem distante de , beeeemmm fraca
# Out:
# np.float64(0.290243040655048)

# %%
from scipy.stats import chi2_contingency

# %%
def cramer_coeficiente(coluna1, coluna2):
  tabela_cruzada = np.array(pd.crosstab(coluna1, coluna2))
  chi2 = chi2_contingency(tabela_cruzada)[0]
  soma = np.sum(tabela_cruzada)
  mini = min(tabela_cruzada.shape)-1
  cramer = np.sqrt(chi2/(soma*mini))
  return cramer

# %%
cramer_coeficiente(dados['COR/RACA/ETNIA'], dados['NIVEL DE ENSINO'])
# Out:
# np.float64(0.04499106580480143)

# %%
tabela_cruzada = pd.crosstab(dados['COR/RACA/ETNIA'], dados['NIVEL DE ENSINO'])
tabela_cruzada
# Out:
# NIVEL DE ENSINO       Doutorado ou Phd  Estudante de Graduação  \
# COR/RACA/ETNIA
# Amarela                              7                      15
# Branca                             127                     365
# Indígena                             0                       2
# Outra                                0                       0
# Parda                               50                     178
# Prefiro não informar                 1                       2
# Preta                                6                      51
#
# NIVEL DE ENSINO       Graduação/Bacharelado  Mestrado  \
# COR/RACA/ETNIA
# Amarela                                  50        14
# Branca                                  999       355
# Indígena                                  4         2
# Outra                                     6         3
# Parda                                   333       113
# Prefiro não informar                     14         1
# ...

# %%
np.array(tabela_cruzada)
# Out:
# array([[  7,  15,  50,  14,   2,   0,  40],
#        [127, 365, 999, 355,  65,   8, 827],
#        [  0,   2,   4,   2,   0,   0,   3],
#        [  0,   0,   6,   3,   1,   0,   7],
#        [ 50, 178, 333, 113,  33,   3, 344],
#        [  1,   2,  14,   1,   0,   1,   7],
#        [  6,  51, 104,  33,   9,   0,  88]])

# %% [markdown]
# #Desafio Correlação

# %%
cramer_coeficiente(dados['NIVEL DE ENSINO'], dados['GENERO'])
# Out:
# np.float64(0.08522666596077663)

# %%
cramer_coeficiente(dados['NIVEL DE ENSINO'], dados['SALARIO'])
# Out:
# np.float64(0.8402384520190614)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Criando uma tabela cruzada
tabela = pd.crosstab(dados['NIVEL DE ENSINO'], dados['FAIXA SALARIAL'])

# Criando o heatmap
plt.figure(figsize=(10,6))
sns.heatmap(tabela, annot=True, fmt="d", cmap="YlGnBu")

plt.title('Heatmap: Nível de Ensino vs Faixa Salarial')
plt.xlabel('Faixa Salarial')
plt.ylabel('Nível de Ensino')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.show()

# %% [markdown]
# ##Salvando nosso arquivo modificado :))

# %%
#Salvando nosso arquivo modificado :))

# %%
dados.to_csv('/content/drive/MyDrive/phyton_pt1.csv', index=False)

# %% [markdown]
# ###Conectando SQL com Pandas

# %%
import sqlite3

# %%
conexao = sqlite3.connect('/content/drive/MyDrive/programaria /status_br')

# %%
query = "SELECT * from Municipios_Brasileiros WHERE Cidade = 'Itaquaquecetuba';"

# %%
query
# Out:
# "SELECT * from Municipios_Brasileiros WHERE Cidade = 'Itaquaquecetuba';"

# %%
pd.read_sql(query, con=conexao)
# Out:
#             Cidade Estado   Regiao  municipio_ID
# 0  Itaquaquecetuba     SP  Sudeste          5043

# %%
#será que existe relação entre os índices de renda e os salários?
#Pra responder isso eu precisaria dos dados daqui e do Pandas!

# %%
pd.read_sql(query, con=conexao)
# Out:
#             Cidade Estado   Regiao  municipio_ID
# 0  Itaquaquecetuba     SP  Sudeste          5043

# %%
dados = pd.read_csv('/content/drive/MyDrive/programaria /phyton_pt1.csv')

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERACAO', 'Quanto tempo de experiência na área de dados você tem?',
# ...

# %%
lista_estados = list(dados['UF ONDE MORA'].unique())

# %%
query = '''
SELECT Municipios_Brasileiros.Estado, AVG(Municipio_Status.renda)
FROM Municipios_Brasileiros
INNER JOIN Municipio_Status ON Municipios_Brasileiros.municipio_ID = Municipio_Status.municipio_ID
WHERE Municipios_Brasileiros.Estado IN ({})
GROUP BY Municipios_Brasileiros.Estado;
'''.format(','.join(['?' for _ in lista_estados]))

# %%
print(query)
#usamos select oq queremos o estado e a média da renda, estados estava em uma tabela e renda em outra.
#inner join! + condicional apenas dados que estao na nossa lista estados
# Out:
# SELECT Municipios_Brasileiros.Estado, AVG(Municipio_Status.renda)
# FROM Municipios_Brasileiros
# INNER JOIN Municipio_Status ON Municipios_Brasileiros.municipio_ID = Municipio_Status.municipio_ID
# WHERE Municipios_Brasileiros.Estado IN (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)
# GROUP BY Municipios_Brasileiros.Estado;

# %%
estados_renda = pd.read_sql(query, con=conexao, params=lista_estados)

# %%
dados.rename(columns={'UF ONDE MORA' : 'ESTADO'}, inplace = True)

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'ESTADO', 'REGIAO ONDE MORA',
#        'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM', 'NIVEL DE ENSINO',
#        'ÁREA DE FORMAÇÃO', 'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERACAO', 'Quanto tempo de experiência na área de dados você tem?',
#        'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?',
# ...

# %%
print(estados_renda.columns.tolist())
# Out:
# ['Estado', 'AVG(Municipio_Status.renda)']

# %%
print(dados.columns.tolist())
# Out:
# ['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA', 'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS', 'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'ESTADO', 'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM', 'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO', 'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR', 'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL', 'FAIXA SALARIAL', 'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?', 'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?', 'SALARIO', 'NOVO NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior', 'GERACAO', 'Quanto tempo de experiência na área de dados você tem?', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?', 'Você está satisfeito na sua empresa atual?', 'Qual o principal motivo da sua insatisfação com a empresa atual?', 'Vo
# ...

# %%
estados_renda.rename(columns={'Estado': 'ESTADO'}, inplace=True)

# %%
dados = dados.merge(estados_renda, on="ESTADO", how= 'left')

# %%
print(dados.columns)
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'ESTADO', 'REGIAO ONDE MORA',
#        'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM', 'NIVEL DE ENSINO',
#        'ÁREA DE FORMAÇÃO', 'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERACAO', 'Quanto tempo de experiência na área de dados você tem?',
#        'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?',
# ...

# %%
correlacao_renda_salario = dados['SALARIO'].corr(dados['AVG(Municipio_Status.renda)'])
print(correlacao_renda_salario)
# Out:
# 0.12083384881429463

# %% [markdown]
# Desafio: Faça a mesma análise utilizando o índice de educação. Existe alguma correlação com salário?🤔

# %%
query_educacao = '''
SELECT Municipios_Brasileiros.Estado, AVG(Municipio_Status.educacao)
FROM Municipios_Brasileiros
INNER JOIN Municipio_Status ON Municipios_Brasileiros.municipio_ID = Municipio_Status.municipio_ID
WHERE Municipios_Brasileiros.Estado IN ({})
GROUP BY Municipios_Brasileiros.Estado;
'''.format(','.join(['?' for _ in lista_estados]))

# %%
estados_educacao = pd.read_sql(query_educacao, con=conexao, params=lista_estados)

# %%
print(dados.columns.tolist())
# Out:
# ['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA', 'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS', 'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'ESTADO', 'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM', 'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO', 'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR', 'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL', 'FAIXA SALARIAL', 'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?', 'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?', 'SALARIO', 'NOVO NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior', 'GERACAO', 'Quanto tempo de experiência na área de dados você tem?', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?', 'Você está satisfeito na sua empresa atual?', 'Qual o principal motivo da sua insatisfação com a empresa atual?', 'Vo
# ...

# %%
print(estados_educacao.columns.tolist())
# Out:
# ['Estado', 'AVG(Municipio_Status.educacao)']

# %%
estados_educacao.rename(columns={'Estado': 'ESTADO'}, inplace=True)

# %%
# precisei renomear de novo, já havia renomeado em DADOS de 'Estado' para 'ESTADO'
# MAS o estados_educacao foi criado depois e separado a partir de um SQL.
#ENTÃO Quando você fez o pd.read_sql(query, con=conexao, params=lista_estados) para criar o estados_educacao, a coluna voltou como 'Estado' (com E maiúsculo e o resto minúsculo).
# Como o read_sql cria um novo DataFrame a partir do banco, ele não sabe das alterações que fiz antes no dados.
#por isso renomeei novamente aqui

# %%
dados = dados.merge(estados_educacao, on="ESTADO", how='left')

# %%
print(dados.columns.tolist())
# Out:
# ['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA', 'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS', 'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'ESTADO', 'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM', 'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO', 'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR', 'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL', 'FAIXA SALARIAL', 'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?', 'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?', 'SALARIO', 'NOVO NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior', 'GERACAO', 'Quanto tempo de experiência na área de dados você tem?', 'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?', 'Você está satisfeito na sua empresa atual?', 'Qual o principal motivo da sua insatisfação com a empresa atual?', 'Vo
# ...

# %%
correlacao_educacao_salario = dados['SALARIO'].corr(dados['AVG(Municipio_Status.educacao)'])
print(correlacao_educacao_salario)
# Out:
# 0.15558020288268756

# %% [markdown]
# # Visualização de Dados

# %%
#relembrando as infos que já temos
dados.head()
# Out:
#    Unnamed: 0                                ID  IDADE FAIXA IDADE     GENERO  \
# 0           0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39  Masculino
# 1           1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34  Masculino
# 2           2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54  Masculino
# 3           3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl   27.0       25-29  Masculino
# 4           4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49   Feminino
#
#   COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0          Parda  Não  Não acredito que minha experiência profissiona...
# 1          Parda  Não  Sim, acredito que a minha a experiência profis...
# 2         Branca  Não                                                NaN
# 3         Branca  Não                                                NaN
# 4         Branca  Não  Não acredito que minha experiência profissiona...
#
# ...

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'ESTADO', 'REGIAO ONDE MORA',
#        'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM', 'NIVEL DE ENSINO',
#        'ÁREA DE FORMAÇÃO', 'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERACAO', 'Quanto tempo de experiência na área de dados você tem?',
#        'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?',
# ...

# %%
genero_counts=dados['GENERO'].value_counts()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.bar(height = genero_counts.values, x = genero_counts.index)
plt.title ('Quantidade de pessoas por gêneros na área de dados')
plt.xlabel("Gênero")
plt.ylabel('Contagem')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import seaborn as sns

# %%
plt.figure()
sns.countplot(data = dados, x='GENERO', palette = 'pastel')
plt.title ('Quantidade de pessoas por gêneros na área de dados')
plt.xlabel("Gênero")
plt.ylabel('Contagem')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-193-a1ea3e839afc>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data = dados, x='GENERO', palette = 'pastel')

# %% [markdown]
# #### *Será que o salário varia de acordo com a idade?*

# %%
salario_por_idade = dados.groupby('IDADE')['SALARIO'].mean()
salario_por_idade
# Out:
# IDADE
# 18.000000     4230.307692
# 19.000000     4519.590909
# 20.000000     5004.272727
# 20.205479     3536.000000
# 21.000000     4578.737179
# 22.000000     4394.689815
# 23.000000     5602.406897
# 24.000000     6151.622449
# 25.000000     7616.392336
# 26.000000     7700.071174
# 27.000000     8237.429766
# 28.000000     9737.938144
# 29.000000     9554.853147
# 30.000000    10316.412686
# 31.000000    10021.462609
# 31.169168     9646.330882
# 32.000000    10843.197778
# 33.000000    11592.718590
# 34.000000    12294.640212
# 35.000000    12435.845105
# 36.000000    12267.966533
# 37.000000    12613.528357
# 38.000000    13802.724874
# 39.000000    13309.082898
# 40.000000    15028.032721
# 41.000000    13578.880952
# 42.000000    11801.037037
# 43.000000    14349.732278
# 44.000000    14665.770147
# 45.000000    16103.431520
# 46.000000    11913.709677
# 47.000000    11156.031250
# 48.000000    12249.714286
# 49.000000    14556.000000
# 50.000000    15740.010181
# ...

# %%
plt.figure()
plt.plot(salario_por_idade.index, salario_por_idade.values, marker='o', linestyle = '--')
plt.xlabel('Idade')
plt.ylabel('Média de salário')
plt.title('Média de salário por idade')
plt.grid(True)
plt.show()

# %%
#testando a biblioteca plotly
import plotly.express as px

# %%
fig = px.line(
    salario_por_idade.reset_index(),
    x='IDADE',
    y='SALARIO',
    title='Média de salário por idade',
    markers=True
    )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#bora fazer um gráfico com dispersão agora!
plt.figure(figsize=(15,5)) #figsize configura o tamanho do gráfico lxa
plt.scatter(dados['IDADE'], dados['SALARIO'], alpha=0.5)
plt.xlabel('Idade')
plt.ylabel('Salário')
plt.title('Dispersão de salário por idade')
plt.grid(True)
plt.show()

# %%
fig = px.scatter(dados, x='IDADE', y='SALARIO', title = 'Dispersão de salário por idade')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Interpretações
# dá pra ver uma grande variabilidade entre os dados e identificar possíveis outliers
# na verdade o salário se mantém naquela faixa de 20k..

# %% [markdown]
# # Desafio
# Vamos olhar mais um notebook do Kaggle, tentem repetir as análises feitas e gerar os gráficos com outros estilos e formatos: https://www.kaggle.com/code/educfrio/an-lise-explorat-ria-de-dados/input

# %%
#optei por fazer no jupyter mesmo, então iniciei importando!

import pandas as pd
dados = pd.read_csv('/content/drive/MyDrive/programaria /municipios_brasileiros.csv')
dados.head()
# Out:
#    codigo_ibge       nome_municipio  codigo_uf  uf        estado  capital  \
# 0      5200050      Abadia de Goiás         52  GO         Goiás        0
# 1      3100104  Abadia dos Dourados         31  MG  Minas Gerais        0
# 2      5200100            Abadiânia         52  GO         Goiás        0
# 3      3100203               Abaeté         31  MG  Minas Gerais        0
# 4      1500107           Abaetetuba         15  PA          Pará        0
#
#    latitude  longitude
# 0 -16.75730   -49.4412
# 1 -18.48310   -47.3916
# 2 -16.19700   -48.7057
# 3 -19.15510   -45.4444
# 4  -1.72183   -48.8788

# %%
# Então comecei a explorar os dados...

# %%
#contagem total de municípios
total_municipios = dados['nome_municipio'].nunique()
print(f"Total de municípios: {total_municipios}")
# Out:
# Total de municípios: 5299

# %%
#histograma de municípios/Estado
import matplotlib.pyplot as plt
import seaborn as sns

# Contagem de municípios por estado
municipios_por_estado = dados['estado'].value_counts()

# Gráfico de barras
plt.figure(figsize=(12,6))
sns.barplot(x=municipios_por_estado.index, y=municipios_por_estado.values, palette='viridis')
plt.xticks(rotation=90)
plt.title('Número de municípios por estado')
plt.xlabel('Estado')
plt.ylabel('Quantidade de Municípios')
plt.show()
# Out:
# <ipython-input-215-d78916b611f7>:10: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
#Ranking dos estados com mais Municípios
top_estados = municipios_por_estado.head(10)
plt.figure(figsize=(10,5))
sns.barplot(x=top_estados.index, y=top_estados.values, palette='mako')
plt.title('Top 10 estados com mais municípios')
plt.xlabel('Estado')
plt.ylabel('Quantidade')
plt.show()
# Out:
# <ipython-input-219-9c23986627b3>:4: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
# Pedi uma dica pro chat gpt de como usar as informações de latitude e longitu e AMEI O RESULTADO!!

# %%
#mapa de dispersão geográfica (latitude e longitude
plt.figure(figsize=(10,10))
sns.scatterplot(x='longitude', y='latitude', data=dados, hue='estado', palette='tab20', legend=False, s=10)
plt.title('Mapa de distribuição dos municípios')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
#quantos municípios são capitais?
capitais = dados[dados['capital'] == True]
print(f"Total de capitais: {capitais.shape[0]}")
# Out:
# Total de capitais: 27
